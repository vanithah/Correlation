# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
cement = pd.read_csv('Concrete_Data.csv')
cement.head(3)
# Out:
#    Cement  Blast  Fly Ash  Water  Superplasticizer      CA     FA  Age    CMS
# 0   540.0    0.0      0.0  162.0               2.5  1040.0  676.0   28  79.99
# 1   540.0    0.0      0.0  162.0               2.5  1055.0  676.0   28  61.89
# 2   332.5  142.5      0.0  228.0               0.0   932.0  594.0  270  40.27

# %%
cement.describe()
# Out:
#             Cement        Blast      Fly Ash        Water  Superplasticizer  \
# count  1030.000000  1030.000000  1030.000000  1030.000000       1030.000000
# mean    281.167864    73.895825    54.188350   181.567282          6.204660
# std     104.506364    86.279342    63.997004    21.354219          5.973841
# min     102.000000     0.000000     0.000000   121.800000          0.000000
# 25%     192.375000     0.000000     0.000000   164.900000          0.000000
# 50%     272.900000    22.000000     0.000000   185.000000          6.400000
# 75%     350.000000   142.950000   118.300000   192.000000         10.200000
# max     540.000000   359.400000   200.100000   247.000000         32.200000
#
#                 CA           FA          Age          CMS
# count  1030.000000  1030.000000  1030.000000  1030.000000
# mean    972.918932   773.580485    45.662136    35.817961
# std      77.753954    80.175980    63.169912    16.705742
# ...

# %% [markdown]
# Correlation coefficient formulas are used to find how strong a relationship is between data. The formulas return a value between -1 and 1, where:
#
# - 1 indicates a strong positive relationship.
# - -1 indicates a strong negative relationship.
# - A result of zero indicates no relationship at all.
#
# https://www.statisticshowto.com/probability-and-statistics/correlation-coefficient-formula/

# %%
cement.corr()
# Out:
#                     Cement     Blast   Fly Ash     Water  Superplasticizer  \
# Cement            1.000000 -0.275216 -0.397467 -0.081587          0.092386
# Blast            -0.275216  1.000000 -0.323580  0.107252          0.043270
# Fly Ash          -0.397467 -0.323580  1.000000 -0.256984          0.377503
# Water            -0.081587  0.107252 -0.256984  1.000000         -0.657533
# Superplasticizer  0.092386  0.043270  0.377503 -0.657533          1.000000
# CA               -0.109349 -0.283999 -0.009961 -0.182294         -0.265999
# FA               -0.222718 -0.281603  0.079108 -0.450661          0.222691
# Age               0.081946 -0.044246 -0.154371  0.277618         -0.192700
# CMS               0.497832  0.134829 -0.105755 -0.289633          0.366079
#
#                         CA        FA       Age       CMS
# Cement           -0.109349 -0.222718  0.081946  0.497832
# Blast            -0.283999 -0.281603 -0.044246  0.134829
# ...

# %%
## to get graphical representation of corr through pairplot
sb.pairplot(cement)

# %% [markdown]
# ### Spearman correlation

# %%
cement.corr(method='spearman').style.background_gradient(cmap='Reds').format("{:.3f}")
# Out:
# <style  type="text/css" >
#     #T_de543de6_ba91_11ea_83c8_005056c00008row0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_de543de6_ba91_11ea_83c8_005056c00008row0_col1 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_de543de6_ba91_11ea_83c8_005056c00008row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_de543de6_ba91_11ea_83c8_005056c00008row0_col3 {
#             background-color:  #fc9b7c;
#             color:  #000000;
#         }    #T_de543de6_ba91_11ea_83c8_005056c00008row0_col4 {
#             background-color:  #fc8161;
#             color:  #000000;
#         }    #T_de543de6_ba91_11ea_83c8_005056c00008row0_col5 {
#             background-color:  #fed9c9;
#             color:  #000000;
#         }    #T_de543de6_ba91_11ea_83c8_005056c00008row0_col6 {
#             background-color:  #fee0d2;
#             color:  #000000;
# ...

# %% [markdown]
# ## A heat map (or heatmap)
# is a graphical representation of data where the individual values contained in a matrix are represented as colors.
#
# A common use of a heat map is to visualize frequency of occurrence of one variable in correlation with another.

# %%
corr = cement.corr()
plt.figure(figsize=(15,8))
ax= sb.heatmap(corr,cmap='Blues', annot = True,cbar=False)
